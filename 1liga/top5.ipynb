# %%
import soccerdata as sd
# Out:
# [12/11/24 13:46:03] INFO     No custom team name replacements found. You can configure these in       ]8;id=634149;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=514583;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_config.py#90\90]8;;\
#                              /home/tymek/soccerdata/config/teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=782569;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=320932;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_config.py#194\194]8;;\
#                              /home/tymek/soccerdata/config/league_dict.json.

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']

# %%
fb = sd.FBref(leagues='ESP-La Liga', seasons=['2425'])
# Out:
# [12/11/24 13:47:44] INFO     Saving cached data to /home/tymek/soccerdata/data/FBref                 ]8;id=145074;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=237814;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/_common.py#263\263]8;;\

# %%
fb.read_leagues()
# Out:
# /home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
#             gender governing_body first_season last_season tier  \
# league
# ESP-La Liga      M           <NA>         8889        2425  1st
#
#                                                      awards  \
# league
# ESP-La Liga  La Liga Best Player, Trofeo Alfredo Di Stéfano
#
#                                               url country
# league
# ESP-La Liga  /en/comps/12/history/La-Liga-Seasons     ESP

# %%
fb.read_seasons()
# Out:
# /home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
#                          format                         url
# league      season
# ESP-La Liga 2425    round-robin  /en/comps/12/La-Liga-Stats

# %%
schedule = fb.read_schedule()
# Out:
# /home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)

# %%
for idx, game in schedule.iterrows():
    print(game['game_id'])
# Out:
# 32bb9a67
# f13e982e
# 3c487349
# 82605913
# e593cd07
# 6f0fac43
# c6b7a6e0
# e826cf9e
# 43c02c2b
# 2a59dd47
# 95447cec
# 0d54805a
# 87bc9bba
# 3c8fe9de
# e11566fd
# 384225d1
# b757e16f
# c6c0a3d3
# b1f96209
# 3f2f6c96
# 050fe7c2
# 6049a447
# f8fc00c7
# acc2bc45
# ef04c85d
# 71669703
# 843a0b94
# 6e8b4c78
# 173a87bb
# d554e8b9
# 3ed1b8ff
# 02bfae4e
# 2053d836
# e79d506b
# 572463cb
# 5a140caa
# 7aa26780
# f8b3c447
# 50cdc0c9
# 3c660029
# 28cd11c2
# 4f2bd132
# 50a17164
# a214487d
# e1e5325c
# 72aa5092
# f166ffc9
# defd20c7
# b5605cb6
# 6ced9ec5
# d2722540
# 613f75be
# f32a65e4
# 9c8b0304
# a46e38e7
# 131899cd
# cddbefd1
# d67421c6
# f5dbb50d
# 75fab2fb
# 79c38937
# c7505bdc
# 618988b7
# 3ee384b4
# b979258f
# 231f83bc
# 07598e53
# 01197df1
# aef7cc8d
# 94fe3705
# d59e698a
# c745f73f
# d5c58cc9
# edd88e45
# 6dfa7503
# 9b519ed0
# 0df1f571
# 650b3ea7
# 4c283fa8
# 3ecbf46e
# 18dc29a4
# d2dd62e7
# fdd30e13
# 8f767bea
# 9bf91e35
# 59703f58
# ba5dd68e
# 7d98a38f
# 069145b6
# c9404de2
# ...

# %%
fb.read_player_match_stats(match_id='384225d1')
# Out:
# /home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
# [12/11/24 13:54:40] INFO     [1/1] Retrieving game with id=384225d1                                    ]8;id=284117;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py\fbref.py]8;;\:]8;id=741693;file:///home/tymek/private/1liga/.venv/lib/python3.11/site-packages/soccerdata/fbref.py#816\816]8;;\
#                                                                         jersey_number  \
#
# league      season game                        team     player
# ESP-La Liga 2425   2024-08-24 Osasuna-Mallorca Mallorca Abdón Prats                 9
# ...
